# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score, roc_curve, auc
from ISLP import load_data

# %%
#!pip install wooldridge

import wooldridge
# List all available datasets
wooldridge.data()

# Load a specific dataset (e.g., 'wage1')
df = wooldridge.data('approval')

# View the first few rows of the dataset
print(df.head())
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/5.1 MB ? eta -:--:--
#    ------------ --------------------------- 1.6/5.1 MB 16.6 MB/s eta 0:00:01
#    ---------------------------------------- 5.1/5.1 MB 23.7 MB/s eta 0:00:00
# ...
#   J.M. Wooldridge (2019) Introductory Econometrics: A Modern Approach,
#   Cengage Learning, 6th edition.
#
#   401k       401ksubs    admnrev       affairs     airfare
#   alcohol    apple       approval      athlet1     athlet2
#   attend     audit       barium        beauty      benefits
#   beveridge  big9salary  bwght         bwght2      campus
#   card       catholic    cement        census2000  ceosal1
#   ceosal2    charity     consump       corn        countymurders
#   cps78_85   cps91       crime1        crime2      crime3
#   crime4     discrim     driving       earns       econmath
#   elem94_95  engin       expendshares  ezanders    ezunem
# ...

# %%
#!pip install matplotlib

import matplotlib.pyplot as plt
import numpy as np

# Data
years = ['2000', '2004', '2008', '2012', '2016', '2020']
democratic_counts = [150, 250, 350, 400, 300, 500]
republican_counts = [200, 600, 1100, 1300, 1500, 1800]

# Bar positions
y_positions = np.arange(len(years))

# Plot
plt.figure(figsize=(8, 6))
plt.barh(y_positions, democratic_counts, color='skyblue', label='Democratic')
plt.barh(y_positions, republican_counts, left=democratic_counts, color='lightcoral', label='Republican')

# Labels and Title
plt.ylabel('Year')
plt.xlabel('Counties')
plt.title('Americans Are More Reliant Than Ever on Government Aid', fontsize=20, wrap=True)
plt.yticks(y_positions, years)
plt.xticks(np.arange(0, 2250, step=250))
plt.legend()

# Notes and Sources
plt.text(-600, -1.5, 'Note: Significant assistance equates to 25% or more of a county’s total personal income. *2020 county total was bolstered by temporary Covid-19-related spending.\nSources: Economic Innovation Group; U.S. Election Atlas; Bureau of Economic Analysis', 
         fontsize=8, ha='left', va='top', wrap=True)

# Display the plot
plt.show()

# %%
# Publication tables

from stargazer.stargazer import Stargazer
from statsmodels.api import OLS
model = OLS(y, X).fit()
stargazer = Stargazer([model])
print(stargazer.render_latex())

# %%
# 3D Graphs
#!pip install mpl_toolkits
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]
z = [10, 5, 4, 8, 9]

ax.scatter(x, y, z, color='red')
plt.show()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement mpl_toolkits (from versions: none)
# ERROR: No matching distribution found for mpl_toolkits

# %%
# Identify columns with NA values and count the number of NA values
na_counts = data.isna().sum()

# Filter to get columns with NA values
na_columns = na_counts[na_counts > 0]

# Print columns with NA values and their counts
print("Columns with NA values and their counts:")
for column, count in na_columns.items():
    print(f"{column}: {count} NA(s)")
